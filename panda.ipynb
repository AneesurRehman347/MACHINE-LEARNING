# %% [markdown]
# <a href="https://colab.research.google.com/github/AneesurRehman347/PANDA-basic/blob/main/panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#df = pd.read_csv('/content/survey_results_schema.csv')

#df
#df.shape

#df.info()

pd.set_option('display.max_columns',9)
pd.set_option('display.max_rows',17)


df_schema = pd.read_csv('/content/sample_data/california_housing_train.csv')
#df_schema
df_schema.head()


df_data = pd.DataFrame(df_schema)
#df_data.longitude
#df_data.columns
#df_data
#df_data.iloc[[0,2],1]

#df_data.loc[[0,2],'happiness']

#df_data().valuecount()



#indexes in data
#set indexs by columns
df_data.set_index('longitude', inplace = True)
#you can reset indexes and can also set index column when reading the file



#df_data.total_bedrooms
#df_data.index

           #index , #column name give exact value of that column

#df_data.loc[-114.31,'latitude' ]
#df_data.sort_index()



#data filter



#filter out the result by conditions
#filt = ( df_data['total_bedrooms'] > 500) & (df_data['housing_median_age']==15)
#df_data.loc[filt,['population','median_income','total_bedrooms']]

filt = df_data['']


#df_data(filt)
# Out:
#            population  median_income  total_bedrooms
# longitude
# -114.31        1015.0         1.4936          1283.0
# -115.48        2097.0         2.3319           666.0
# -115.99         515.0         2.0109           536.0
# -116.06        4507.0         2.2466          2331.0
# -116.39        2709.0         1.9779          1149.0
# ...               ...            ...             ...
# -122.73        1629.0         3.7132           690.0
# -122.90         835.0         1.9141           544.0
# -123.34        1064.0         1.8967           535.0
# -124.16        1532.0         2.1829           569.0
# -124.19        1645.0         1.6654           714.0
#
# [215 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['population'].plot(kind='hist', bins=20, title='population')
# ...

# %%
# @title Default title text
import pandas as pd


df = pd.read_csv('/content/sample_data/survey_results_schema.csv',index_col = 'qid')


pd.set_option('display.max_rows',79)
df.sort_values(by=['qname'],ascending=True)

df.force_resp
#filt = (df['type'] == 'MC')
#print(filt)
#filt = df['question'].set
#df.loc[filt]
filt = df['question'].str.contains('code')
df.loc[filt,['question']]
# Out:
#                                                  question
# qid
# QID16   <div><span style="font-size:19px;"><strong>Hel...
# QID2    Which of the following options best describes ...
# QID297  Which of the following best describes the code...
# QID276  How did you learn to code? Select all that apply.
# QID281  What online resources do you use to learn to c...
# QID306  What online courses or certifications do you u...
# QID34   NOT including education, how many years have y...
