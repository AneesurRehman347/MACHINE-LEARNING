# %% [markdown]
# <a href="https://colab.research.google.com/github/AneesurRehman347/MACHINE-LEARNING/blob/main/EDA_on_Zomato_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


df = pd.read_csv('/content/zomato.csv',encoding='latin-1') #encoing thing search

df.head()

df.columns
#or
# df.info() # basic overview of data


df.describe() #describe every numerical feature


#EDA ALL THINGS TO DO
# 1. MISSING VALUES
# 2. EXPLORE ABOUT NUMERICAL VARIABLE
# 3. EXPLORE ABOUT CATEGORICAL VARIABLE
# 4. REALATIONSHIP BETWEEN FEATURE

 #GIVE YOU THE SUM OF MISSING VALUES IN EVERY FEATURE
df.isnull().sum()
# RELASHIONSHIP BTW NULL FEATURE WITH OTHER FEATURES?

# to get all feature in the data set that contain null values
[features for features in df.columns if df[features].isnull().sum()>1]

#visual representation of the null values
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')


# a new data set
df_country = pd.read_excel('/content/Country-Code.xlsx')
df_country.columns


# merge two data sets on 'which common column' and on which data set left or right or inner
final_df = pd.merge(df,df_country,on = 'Country Code',how = 'left')


#to get data types of all column
final_df.dtypes

final_df.columns
country_names =final_df.Country.value_counts().index
country_values =final_df.Country.value_counts().values

# reason behind doing above value count for every country zomato order is to create pie chart

# from this plot we can get the maximum number of transaction in top 3 country

# plt.pie(country_values[:3],labels = country_names[:3],autopct="%1.2f%%")

# observation : zomato max transaction are from india,USA AND UK repectiverly


#rating observation

#reset index will reset data set index to 0 and size will give there combine result

ratings = final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns ={0:'Rating Count'}) # group rating features


#observation
# max rating are 0  which means no ratings
# when rating is between 4.5 to 4.9 --> Excellent
# when rating is between 4.0 to 4.4 --> Very Good
# when rating is between 3.5 to 3.9 --> Good
# when rating is between 2.5 to 3.4 --> Average
# when rating is between 1.8 to 2.4 --> poor



#diagrams plots

plt.rcParams['figure.figsize'] = (12, 6)
sns.set(rc={'axes.facecolor':'blue', 'figure.facecolor':'white'})
# sns.barplot(x ="Aggregate rating",y="Rating Count",hue = 'Rating color',data = ratings,palette=['white','red','orange','green','green'])

# ratings.head(20)
# ratings.describe()
#observation
# 1.not rated is very high
# 2. mean is 3.2


#find the countries with 0 ratings


final_df[final_df['Rating color'] == 'White'].groupby('Country').size().reset_index()

# find out which currency is used by which country?

final_df.head()

final_df.Currency.unique()
cntry_curr = final_df[['Currency','Country']].groupby(['Currency','Country']).size().reset_index()
cntry_curr

# which country do have online delivery option
final_df.columns
online_del =final_df[ final_df['Has Online delivery']=='Yes'].Country.value_counts()
online_del

#create a pie chart for cities with top 3 transaction
cty_names =final_df.City.value_counts().index
cty_values =final_df.City.value_counts().values

plt.pie(cty_values[:3],labels = cty_names[:3],autopct="%1.2f%%")


#find top 10 cuisines
final_df.Cuisines.value_counts().head(3)
# final_df.columns

## Numerical Variable
